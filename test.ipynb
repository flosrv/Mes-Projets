# %%
import pandas as pd

# %%
df = pd.read_csv('data_engineer_types.csv')
df
# Out:
#                        Unnamed: 0  \
# 0              Objectif principal
# 1                 Type de données
# 2          Technologies utilisées
# 3                        Stockage
# 4          Traitement des données
# 5             Langages principaux
# 6                  Infrastructure
# 7        Modélisation des données
# 8                 Outils utilisés
# 9                     Cas d’usage
# 10                Passage vers BI
# 11          Passage vers Big Data
# 12  Passage vers Machine Learning
# 13             Passage vers Cloud
# 14  Passage vers Data Warehousing
#
#                                Data Engineer Big Data  \
# 0   Manipuler de grandes quantités de données non ...
# 1   Données massives : Capteurs IoT, logs, réseaux...
# 2   Hadoop, Spark, Kafka, Flink, NoSQL (MongoDB, C...
# 3               HDFS, S3, NoSQL, Data Lakes, DynamoDB
# 4   Traitement des données en batch et en temps ré...
# 5   Python, Scala, Java, SQL, Bash, PySpark, Hive,...
# ...
